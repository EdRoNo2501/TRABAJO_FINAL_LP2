# %% [markdown]
# # Venta de Casas en Peru
#
# ## Objetivos
#
# 1. El proyecto consistirá en extraer los precios de las casas en venta del sitio web [Properati](https://www.properati.com.pe/s/casa/venta) además del lugar y enlace, todo esto mediante el **web scraping**.
# 2. Este sitio web cuenta con unas 186 paginas y mas de 6000 mil resultados es por ello que se permitirá al usuario escoger la cantidad de páginas, así como también escoger el precio mínimo y máximo.
# 3. Los precios obtenidos serán tanto en dólares como en soles, siendo el de principal foco el dólar porque con el previo análisis de este proporcionara al usuario si les conveniente adquirir una casa.
#
#
# ## Tutorial
# 1. Lo primero que necesitaremos sera el enlace la pagina que queremos webcrapear [Properati](https://www.properati.com.pe/s/casa/venta).
# 2. Prepararemos las librerias que utlizaremos, en caso de no tener instalarlas usado pip por ejemplo

# %%
#!pip install requests beautifulsoup4

# %% [markdown]
# ### Librerias
#
# - `requests`: Permite realizar solicitudes HTTP y obtener el contenido de una página web. Se utiliza para enviar solicitudes a un servidor y recibir la respuesta correspondiente. En el contexto del web scraping, se utiliza para obtener el HTML de una página web y luego analizarlo con BeautifulSoup.
#
# - `BeautifulSoup`: Es utilizada para analizar y extraer datos de documentos HTML y XML. Proporciona herramientas para buscar, navegar y manipular la estructura del documento. En el contexto del web scraping, BeautifulSoup se utiliza para extraer información específica de las páginas web.
#
# - `pandas`: Proporciona estructuras de datos y herramientas para el análisis y manipulación de datos. Ofrece una estructura de datos llamada DataFrame, que es útil para organizar y trabajar con datos tabulares. En el contexto del web scraping, pandas se utiliza para almacenar los datos extraídos en un formato tabular y realizar operaciones y análisis posteriores.
#
# - `re`: Proporciona operaciones de coincidencia de patrones mediante expresiones regulares.
#
# - `tabulate`: Permite representar datos tabulares en forma de tablas. Proporciona una forma conveniente de formatear y visualizar datos en una estructura de tabla legible.
#
# **Codigo:**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from tabulate import tabulate

# %% [markdown]
# 3. Comprobar que la pagina web es apta para el webscrapeo. Aqui una guia : ![image.png](attachment:image.png)

# %%
url = 'https://www.properati.com.pe/s/casa/venta' # enlace de la pagina a webscrapear
response = requests.get(url) # recibe la respuesta del server de la pagina
html_content = response.content # devuelve el contenido de la pagina en formato byte
response.status_code # con esto comprobamos (codigo)
# Out:
# 200

# %% [markdown]
# ```python
# response.text # Muestra el html como cade de texto
# ```

# %% [markdown]
# ### 1. Webscrapeo
# - Esta es una prueba solamente con el numero de paginas en donde ademas se explica como funciona cada codigo.

# %%
import requests
from bs4 import BeautifulSoup

def obtener_datos(num_paginas):
    # URL base
    url_base = 'https://www.properati.com.pe/s/casa/venta/'

    # Listas para almacenar los precios, lugares y enlaces
    precios = []
    lugares = []
    enlaces = []

    # Recorrer las páginas
    for i in range(1, num_paginas + 1):
        # Construir la URL de la página actual
        url_pagina = f'{url_base}{i}'

        # Realizar la solicitud HTTP a la página actual
        response = requests.get(url_pagina)

        # Verificar si la solicitud fue exitosa
        if response.status_code == 200:
            # Obtener el contenido HTML de la página
            html = response.text

            # Crear un objeto BeautifulSoup para parsear el HTML
            soup = BeautifulSoup(html, 'html.parser')

            # Encontrar los elementos de precios en la página actual
            elementos_precios = soup.find_all('div', class_='price')

            # Obtener los precios de los elementos y agregarlos a la lista
            precios_pagina = [elemento.get_text(strip=True) for elemento in elementos_precios]
            precios.extend(precios_pagina)

            # Encontrar los elementos de lugares en la página actual
            elementos_lugares = soup.find_all('div', class_='listing-card__location')

            # Obtener los lugares de los elementos y agregarlos a la lista
            lugares_pagina = [elemento.get_text(strip=True) for elemento in elementos_lugares]
            lugares.extend(lugares_pagina)

            # Encontrar los elementos de enlaces en la página actual
            elementos_enlaces = soup.find_all('a', href=lambda href: href and href.startswith('/detalle'))

            # Obtener los enlaces completos y agregarlos a la lista
            enlaces_pagina = [f'https://www.properati.com.pe{elemento["href"]}' for elemento in elementos_enlaces]
            enlaces.extend(enlaces_pagina)
        else:
            print(f'Error al acceder a la página {url_pagina}')
            continue

    return precios, lugares, enlaces

# Obtener el número de páginas a recorrer
num_paginas = int(input('Ingrese el número de páginas a recorrer: '))

# Obtener los precios, lugares y enlaces de las casas en las páginas especificadas
precios, lugares, enlaces = obtener_datos(num_paginas)

# Imprimir los precios, lugares y enlaces obtenidos
for precio, lugar, enlace in zip(precios, lugares, enlaces):
    print(f'Precio: {precio}, Lugar: {lugar}, Enlace: {enlace}')
# Out:
# Ingrese el número de páginas a recorrer: 4
# Precio: USD750,000, Lugar: Los Rosales, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-d7f6-3fe40920d3be-e9c394a9-8bef-4b13
# Precio: USD560,000, Lugar: Ur. Casuarinas Sur, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5348-5f529e01db4d-e946fa75-a559-43e8
# Precio: USD630,000, Lugar: La Encantada De Villa, Provincia de Lima, Gobierno Regional de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3637-534a8607857f-e1a2f61b-8dc1-4618
# Precio: USD320,000, Lugar: A.h General Jose de San Martin, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c653-9f73ed1f4354-c0829117-a5c7-4ee1
# Precio: USD640,000, Lugar: Ur. Jacaranda, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-84a8-44ce0143a76-ae76846c-97f1-4170
# Precio: USD512,000, Lugar: Ur. Aurora, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-a476-2760419c7547-9b004e79-b2cc-4829
# Precio: USD149,000, Lugar: Nuevo Chimbote, Santa, Ancash, Enlace: https://www.properati.com.pe/detalle/14032-32-3a85-1e3ffe3b76e0-89bfbb65-afd5-4f8c
# Precio: USD365,000, Lugar: Ur. Santa Patricia Etapa I, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f007-1587436fbe65-891f0b5b-8d37-485e
# Precio: S/.415,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-18a2-fb30be3aa841-6f39d440-870a-120e
# Precio: USD400,000, Lugar: Ah. Bocanegra Sector F, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-ce5f-66b002acd446-3f216980-92f5-415a
# Precio: USD1,300,000, Lugar: San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c858-e714d33b4c94-29b6433f-b268-4727
# Precio: USD2,500,000, Lugar: Ur. Humboldt, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-2e96-4a06117c3594-263d48ae-976f-4390
# Precio: USD1,100,000, Lugar: Ur. Santa Ines, San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-60f8-147c0685e41d-24aad2e0-b605-4563
# Precio: S/.790,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-7d43-ed83c7cd1d6c-1f1b8b93-9fbb-4e09
# Precio: USD400,000, Lugar: Ur. Juan Xxiii, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1de0-a49b0a4a7617-49ab306-a685-4d63
# Precio: USD1,750,000, Lugar: Country Club, Urb Risso, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-bdef-a876d2a7b64a-2b73c23-a997-4302
# Precio: USD210,000, Lugar: Ur. San Miguelito, San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f42a-f4904ff4422-fe8aa36c-8f8d-4cec
# Precio: USD149,000, Lugar: Ur. Las Delicias De Villa, Chorrillos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5cbd-99632ff875cb-f99b05f8-aa3f-43da
# Precio: USD363,000, Lugar: Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9813-2e1f9a2b1223-f06c527f-8a56-462f
# Precio: USD280,000, Lugar: Huarochirí, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-cc32-a106eec6a716-ef9ee19c-9f17-4e18
# Precio: USD980,000, Lugar: La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1625-2d8e36a03b9e-ed5a7520-9587-120e
# Precio: USD165,000, Lugar: San Martín de Porres, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-728a-e1eac6c25ba8-e7a3554b-a169-4bd6
# Precio: USD600,000, Lugar: Ur. Humboldt, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e9cf-7866ade8a977-e13278f9-a602-4235
# Precio: S/.245,000, Lugar: Lurin, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-40-479e37126484-dbbfc926-8f85-4635
# Precio: S/.395,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-a88f-db19117fd35f-db7d134f-8ef3-4ac1
# Precio: USD330,000, Lugar: Ur. Pro Quinto Sector Ii Etapa, Los Olivos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-daaa-a7ed7999e37a-db1fd7ec-bf51-4818
# Precio: USD1,600,000, Lugar: Hu. Cercado De Miraflores, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ecdf-27843598cf70-d8da7e90-9520-4a02
# Precio: USD3,750,000, Lugar: Ur. Cerros De Camacho, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3df9-114eeae511fc-d2a37951-b279-489f
# Precio: USD300,000, Lugar: Ur. La Luz, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-a2ba-bd6a63c866c2-d2950c20-a572-120d
# Precio: USD400,000, Lugar: Ur. El Abanico, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-183c-314700894caf-d09b4fc0-83e0-4542
# Precio: USD350,000, Lugar: Ur. Las Viñas (Las Viñas De La Molina Vieja), La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-4528-9d41a1446f3-ce18a7c0-826a-4262
# Precio: USD150,000, Lugar: Ah. Villa Escudero, Mi Perú, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-d3a6-b1263714196e-bc62e3eb-b5b0-4c5d
# Precio: USD450,000, Lugar: Ur. Portada Del Sol Etapa I (A.E.M.G), La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ccce-19b78ca069a5-b5a8738c-bb08-4ad2
# Precio: USD430,500, Lugar: Ur. Los Halcones, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-b062-36a8e52acd6b-b4a8c31e-b825-438b
# Precio: USD150,000, Lugar: Ur. Mariscal Andres Avelino Caceres Sector 2, San Juan de Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3f86-c3e5ce34fd05-b2ba8915-bd22-4e22
# Precio: USD390,000, Lugar: Ur. Isla Verde, Pueblo Libre, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-802-94a2801d7e66-af2e6220-82ab-4112
# Precio: USD529,000, Lugar: Ur. Valle Hermoso Este, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3d53-bf9b97b45e3b-a3a11559-b5d0-4ac7
# Precio: USD308,000, Lugar: Ur. Paulo Vi, San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-99bf-332699eaf1e5-a339a1a7-99da-43eb
# Precio: USD217,000, Lugar: Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-46b2-77e154d0fe30-9fe91c63-9fd6-4742
# Precio: USD215,000, Lugar: Ur. Los Laureles, Chorrillos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c74f-7c31e56360a8-9018fe8a-9450-45b3
# Precio: USD3,200,000, Lugar: Ur. Santa Teresa, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-fee2-871e3514a0e0-8defa0e1-abb5-4706
# Precio: USD250,000, Lugar: Ur. Aurora, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1acc-adbabbab89e2-852e1641-8349-4b6b
# Precio: USD570,000, Lugar: Ur. Jacaranda, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1e8f-336f143ff31e-8509da3a-934d-441e
# Precio: USD315,000, Lugar: Ur. Portada Del Sol Etapa Iii (A.E.M.G), La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-cd3b-9b74f4d6e62c-84e7c1c6-96f2-40bd
# Precio: USD218,000, Lugar: Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-93ea-86c18a6ddb9c-8465f386-beee-46dc
# Precio: USD850,000, Lugar: Ur. San Damian, San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e135-312eb1a828b0-7c1b2e7f-b1dc-4d0d
# Precio: USD981,500, Lugar: Cusco, Enlace: https://www.properati.com.pe/detalle/14032-32-202-82a2b3202747-7b032a16-bd57-436b
# Precio: USD118,000, Lugar: Carabayllo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-31be-bb0651ce43a7-74ffed01-84b9-4600
# Precio: USD50,000, Lugar: Co. Victor Andres Belaunde, Puente Piedra, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9a8d-34a2e59a9039-6166eba3-9e3e-4082
# Precio: USD345,000, Lugar: Co. Llanavilla, Villa El Salvador, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-8c46-b28be6dd8f97-5d291249-a4e4-4ed8
# Precio: USD230,000, Lugar: Re. Las Torres De San Borja, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-dcdd-960de19acdbc-54cd83b8-ab0a-47c5
# Precio: USD320,000, Lugar: Ur. Los Proceres, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-20e5-e527c496e223-52695d95-822e-4029
# Precio: USD598,000, Lugar: Ur. Los Pinares, Los Olivos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-48a9-905e3bb511fb-51c0a892-b936-48fc
# Precio: USD140,000, Lugar: Santa María, Huaura, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c888-773c45e5fb82-4b53e9a3-8a21-44a1
# Precio: USD299,000, Lugar: Re. Monterrico Ampliacion, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-15d9-76ebd6bc274a-4a02fc81-ac2d-41fb
# Precio: USD315,000, Lugar: Huacho, Huaura, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-73b3-d2e9ce8bb0a4-4003befe-951c-417d
# Precio: USD170,000, Lugar: Co. Guadalupe, Los Olivos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-41b6-9dd737c6255b-39e1a342-ba2a-4499
# Precio: S/.498,000, Lugar: Ah. Moron, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-4b8d-f2951d223349-3429594d-9548-47d8
# Precio: USD1,000,000, Lugar: Ur. Santa Beatriz, Jesús María, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5aa-817f164b7e94-318e0333-9434-41ea
# Precio: USD92,000, Lugar: Villa El Salvador, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-15f8-694c38f09c80-2fd15050-8b6d-120e
# Precio: USD329,000, Lugar: Ur. Rinconada Alta Etapa I, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-deaf-388fb746e4d9-2f78269d-b9c5-48fc
# Precio: USD230,000, Lugar: Ur. La Perla, La Perla, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-e924-95d23aa5f7fc-25017058-86c8-4a05
# Precio: USD375,000, Lugar: Ag. Cerro Colorado, Cerro Colorado, Arequipa, Enlace: https://www.properati.com.pe/detalle/14032-32-38f1-286fd91af5a-1f7de094-b8fa-47a6
# Precio: USD650,000, Lugar: Ur. La Encantada, Chorrillos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-b15e-c022e5021d82-1bbe1c6a-a62b-48d4
# Precio: USD730,000, Lugar: Ur. Los Patricios (San Felipe), Jesús María, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e6b-ff31dd8c0e7-1a61f89d-83c6-4cff
# Precio: S/.79,000, Lugar: Sunampe, Chincha, Ica, Enlace: https://www.properati.com.pe/detalle/14032-32-163a-233d08a38887-11bd6670-862a-120e
# Precio: USD850,000, Lugar: Re. Monterrico, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-fe15-dbcb4a57b334-1192b495-9f2a-42e2
# Precio: USD180,000, Lugar: Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-bf58-d08c9992aed3-10e61eec-925f-4ccc
# Precio: USD115,000, Lugar: Ur. Santa Isabel, Carabayllo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e37f-d70b9738e258-e4ae8b7-9b40-4d19
# Precio: USD164,500, Lugar: Comas, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-6f84-f92b11b86181-df50fd4-a1ba-4a69
# Precio: USD350,000, Lugar: San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f20f-6571621e92fe-98987dd-bff1-4b83
# Precio: USD750,000, Lugar: Ur. El Abanico, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-38ff-61477df05829-97bf9fd-8ab5-4d4d
# Precio: USD1,700,000, Lugar: Ur. El Cortijo Etapa I, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-7f91-4d85e0153f9c-310a8f7-839b-4fd9
# Precio: USD77,900, Lugar: Ah. Bello Horizonte, Huanchaco, Trujillo, La Libertad, Enlace: https://www.properati.com.pe/detalle/14032-32-130a-c9a48717fabf-fd421e20-9c3d-120e
# Precio: USD92,000, Lugar: Ur. Los Sauces, Ate, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-90a1-daf0485ef661-f61b4a5a-9a82-4130
# Precio: USD185,000, Lugar: Ah. El Agustino, El Agustino, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ba6a-d994f83ab49c-eeb4b5a0-b2ce-120d
# Precio: USD265,000, Lugar: Ur. Antares Etapa Iii, San Martín de Porres, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-af5d-e1230726541e-ed200b5f-bf9d-46e1
# Precio: USD300,000, Lugar: Ur. El Pinar Sector Parcela G, Comas, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-7e4b-9747e837d405-eb61f9a9-9c2d-4889
# Precio: USD265,000, Lugar: Ur. Maranga Etapa Ii, San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ed5b-ce2b5d167105-e7aaff33-8e26-4f02
# Precio: USD1,280,000, Lugar: Ur. Ampliacion San Isidro, San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-4ea4-9f0cf5e88778-e4c540b6-bc66-4441
# Precio: USD65,000, Lugar: Pisco, Ica, Enlace: https://www.properati.com.pe/detalle/14032-32-bf78-6ee735946865-df393b57-967e-4de2
# Precio: USD74,000, Lugar: Ur. Pedregal Bajo, Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-af4f-21b06915ded9-d6ed5b84-bce8-403c
# Precio: USD85,000, Lugar: Ur. Santa Maria I Etapa, Carabayllo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-754f-e26b31ae9a80-d56d9444-8a51-4469
# Precio: USD320,000, Lugar: Ur. Maranga Etapa Iii, San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-4dfc-ddbeaae0e993-d1ee68ae-842e-4a8f
# Precio: USD160,000, Lugar: Santa Eulalia, Huarochirí, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ee46-2635ae2a30cc-d0b4c7a8-826f-4521
# Precio: USD165,000, Lugar: Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-7f6a-11c62cd08665-cde30b0a-84cf-4ce4
# Precio: USD1,950,000, Lugar: Urb Santa Maria de Chosica, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-8ff4-9671a23af3fd-c18ad058-97f3-4d0e
# Precio: S/.285,000, Lugar: Chiclayo, Lambayeque, Enlace: https://www.properati.com.pe/detalle/14032-32-3bd-e4c92ed9463a-bdf7edb2-9790-4498
# Precio: USD146,000, Lugar: Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e62f-c5cf97f222d2-b8bb6bfd-9fd2-4229
# Precio: USD1,050,000, Lugar: Ur. Club Golf De Los Incas, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9e8e-2f80fa3d92ee-b4272026-bafb-4a0e
# Precio: USD350,000, Lugar: Ot Centro Historico de Piura, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-984d-e059c74f011f-a7d3c43b-a6f9-365a
# Precio: USD450,000, Lugar: Ur. Las Viñas (Las Viñas De La Molina Vieja), La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e163-7fe5db3fa91-a76a66c0-b333-120d
# Precio: USD240,000, Lugar: Ur. Los Girasoles (Los Girasoles De Huampani), Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c5c0-2291495b1126-a644ff16-8058-4d8d
# Precio: USD139,900, Lugar: Ur. La Rinconada, Trujillo, La Libertad, Enlace: https://www.properati.com.pe/detalle/14032-32-36e3-8f166d646dbb-a0a86653-9fbf-4715
# Precio: USD270,000, Lugar: Horizonte de Zárate, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-124b-efa10eb4a321-9f63ff1c-9487-382f
# Precio: USD100,000, Lugar: Ur. Carlos Stein 1, José Leonardo Ortiz, Chiclayo, Lambayeque, Enlace: https://www.properati.com.pe/detalle/14032-32-4999-8cc2a5a55dac-9f24dc2d-93fb-486b
# Precio: USD230,000, Lugar: Ur. Los Girasoles (Los Girasoles De Huampani), Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9762-be8b35cc96a3-9b655de8-b60c-4297
# Precio: USD265,000, Lugar: Ur. La Luz, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9003-21c4ef61ad24-986a85a0-886d-4035
# Precio: USD150,000, Lugar: Tarapoto, San Martín, Enlace: https://www.properati.com.pe/detalle/14032-32-7943-d8e3c2aa10e1-97531092-a30e-4c19
# Precio: USD535,000, Lugar: Ur. Los Granados, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-eaf1-857fe445f0d4-86e1c1e0-af4d-120d
# Precio: USD120,000, Lugar: Ch. Antonia Moreno De Caceres Sector 2 (Ciudad Del Deporte), Ventanilla, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-69f5-dd6f87a981e4-7ea569ae-9bb6-4e78
# Precio: USD150,000, Lugar: Huanta, Ayacucho, Enlace: https://www.properati.com.pe/detalle/14032-32-52e6-f650ba2befb6-7be92bb6-b39f-499c
# Precio: USD330,000, Lugar: Ur. San Felipe, Jesús María, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1f00-20faa7e0817d-76ac0bba-87d0-49f2
# Precio: USD220,000, Lugar: San Martín de Porres, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-155c-6b3582cf793a-74b82410-a493-120e
# Precio: USD165,000, Lugar: Cp. Chosica, Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-2bd4-2ff74f9108d5-72e7e067-96e0-44ac
# Precio: USD74,000, Lugar: Ur. Pedregal Bajo, Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-b220-a8b83cae4a0c-685bb4fb-b734-4a8a
# Precio: USD65,000, Lugar: San Andrés, Pisco, Ica, Enlace: https://www.properati.com.pe/detalle/14032-32-7ad9-3ec277011f41-5b628542-90cf-4c2a
# Precio: USD449,000, Lugar: La Victoria, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-13d8-fb6d3a91b913-5b323010-980d-120e
# Precio: USD280,000, Lugar: Ur. Corporacion El Agustino, El Agustino, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-eade-11bbc7d466a1-58e5bbb0-8f5d-120d
# Precio: USD65,000, Lugar: Ventanilla, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-1b0-793a12f3f27f-5366abc0-8b15-120e
# Precio: USD1,290,000, Lugar: Re. Monterrico Ampliacion, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-20f3-ea5c926c0ddb-4d062fb7-bba0-43c7
# Precio: USD479,999, Lugar: Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-171c-78caf6beac5f-3bffc360-99a9-469a
# Precio: USD149,000, Lugar: Ah. Tapada, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ce24-a6825c82bfcd-3b926336-b6d0-4164
# Precio: USD185,000, Lugar: Pj. Señor De Los Milagros Zona Ii, Comas, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-8077-79af8c59aa7c-35dbf480-8a50-3b45
# Precio: USD80,000, Lugar: Cp. Viuda, Pachacamac, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5847-6c3a23371773-30fe83eb-86dc-4141
# Precio: USD2,508,800, Lugar: Urb San Eduardo, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-6b44-fe95acc3bb3c-30ebbf0e-abae-4328
# Precio: USD240,000, Lugar: Ur. Los Girasoles (Los Girasoles De Huampani), Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ea1-3d99682ec1e9-2eecf8a8-8669-46a3
# Precio: USD520,000, Lugar: Ur. La Encantada, Chorrillos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f15f-a6d21257c943-246e9c6a-8ee6-43bf
# Precio: USD170,000, Lugar: Lurigancho, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1185-c1dd2aa9b617-1e89401c-9c1a-42c4
# Precio: USD160,000, Lugar: Ur. San Juan Sector D, San Juan de Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-85c-4b7bff065302-1b640f53-968c-4c02

# %% [markdown]
# ### 2. Clase y definicion
# - Se usa una clase para facilitar el proceso ademas que aca si se usa el precio maximo y minimo

# %%
import requests
from bs4 import BeautifulSoup
import re

class ProperatiScraper:
    def __init__(self):
        self.url_base = 'https://www.properati.com.pe/s/casa/venta/'
    
    def obtener_datos(self, num_paginas, precio_min, precio_max):
        precios = []
        lugares = []
        enlaces = []

        for i in range(1, num_paginas + 1):
            url_pagina = f'{self.url_base}{i}'
            response = requests.get(url_pagina)

            if response.status_code == 200:
                html = response.text
                soup = BeautifulSoup(html, 'html.parser')

                elementos_precios = soup.find_all('div', class_='price')
                precios_pagina = [elemento.get_text(strip=True) for elemento in elementos_precios]

                elementos_lugares = soup.find_all('div', class_='listing-card__location')
                lugares_pagina = [elemento.get_text(strip=True) for elemento in elementos_lugares]

                elementos_enlaces = soup.find_all('a', href=lambda href: href and href.startswith('/detalle'))
                enlaces_pagina = [f'https://www.properati.com.pe{elemento["href"]}' for elemento in elementos_enlaces]

                for precio, lugar, enlace in zip(precios_pagina, lugares_pagina, enlaces_pagina):
                    # Extraer solo los valores numéricos del precio
                    precio_numerico = re.findall(r'\d+', precio)
                    if precio_numerico:
                        precio_float = float(''.join(precio_numerico))

                        if precio_min <= precio_float <= precio_max:
                            precios.append(precio)
                            lugares.append(lugar)
                            enlaces.append(enlace)
            else:
                print(f'Error al acceder a la página {url_pagina}')
        
        return precios, lugares, enlaces


# Obtener el número de páginas a recorrer
num_paginas = int(input('Ingrese el número de páginas a recorrer: '))

# Obtener el precio mínimo y máximo del usuario
precio_min = float(input('Ingrese el precio mínimo: '))
precio_max = float(input('Ingrese el precio máximo: '))

# Crear instancia del scraper
scraper = ProperatiScraper()

# Obtener los precios, lugares y enlaces de las casas en las páginas especificadas
precios, lugares, enlaces = scraper.obtener_datos(num_paginas, precio_min, precio_max)

# Imprimir los precios, lugares y enlaces obtenidos
for precio, lugar, enlace in zip(precios, lugares, enlaces):
    print(f'Precio: {precio}, Lugar: {lugar}, Enlace: {enlace}')
# Out:
# Ingrese el número de páginas a recorrer: 1
# Ingrese el precio mínimo: 1000
# Ingrese el precio máximo: 100000000000000000
# Precio: USD750,000, Lugar: Los Rosales, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-d7f6-3fe40920d3be-e9c394a9-8bef-4b13
# Precio: USD560,000, Lugar: Ur. Casuarinas Sur, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5348-5f529e01db4d-e946fa75-a559-43e8
# Precio: USD630,000, Lugar: La Encantada De Villa, Provincia de Lima, Gobierno Regional de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3637-534a8607857f-e1a2f61b-8dc1-4618
# Precio: USD320,000, Lugar: A.h General Jose de San Martin, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c653-9f73ed1f4354-c0829117-a5c7-4ee1
# Precio: USD640,000, Lugar: Ur. Jacaranda, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-84a8-44ce0143a76-ae76846c-97f1-4170
# Precio: USD512,000, Lugar: Ur. Aurora, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-a476-2760419c7547-9b004e79-b2cc-4829
# Precio: USD149,000, Lugar: Nuevo Chimbote, Santa, Ancash, Enlace: https://www.properati.com.pe/detalle/14032-32-3a85-1e3ffe3b76e0-89bfbb65-afd5-4f8c
# Precio: USD365,000, Lugar: Ur. Santa Patricia Etapa I, La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f007-1587436fbe65-891f0b5b-8d37-485e
# Precio: S/.415,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-18a2-fb30be3aa841-6f39d440-870a-120e
# Precio: USD400,000, Lugar: Ah. Bocanegra Sector F, Callao, Enlace: https://www.properati.com.pe/detalle/14032-32-ce5f-66b002acd446-3f216980-92f5-415a
# Precio: USD1,300,000, Lugar: San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-c858-e714d33b4c94-29b6433f-b268-4727
# Precio: USD2,500,000, Lugar: Ur. Humboldt, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-2e96-4a06117c3594-263d48ae-976f-4390
# Precio: USD1,100,000, Lugar: Ur. Santa Ines, San Isidro, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-60f8-147c0685e41d-24aad2e0-b605-4563
# Precio: S/.790,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-7d43-ed83c7cd1d6c-1f1b8b93-9fbb-4e09
# Precio: USD400,000, Lugar: Ur. Juan Xxiii, San Borja, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1de0-a49b0a4a7617-49ab306-a685-4d63
# Precio: USD1,750,000, Lugar: Country Club, Urb Risso, Provincia de Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-bdef-a876d2a7b64a-2b73c23-a997-4302
# Precio: USD210,000, Lugar: Ur. San Miguelito, San Miguel, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-f42a-f4904ff4422-fe8aa36c-8f8d-4cec
# Precio: USD149,000, Lugar: Ur. Las Delicias De Villa, Chorrillos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-5cbd-99632ff875cb-f99b05f8-aa3f-43da
# Precio: USD363,000, Lugar: Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-9813-2e1f9a2b1223-f06c527f-8a56-462f
# Precio: USD280,000, Lugar: Huarochirí, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-cc32-a106eec6a716-ef9ee19c-9f17-4e18
# Precio: USD980,000, Lugar: La Molina, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-1625-2d8e36a03b9e-ed5a7520-9587-120e
# Precio: USD165,000, Lugar: San Martín de Porres, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-728a-e1eac6c25ba8-e7a3554b-a169-4bd6
# Precio: USD600,000, Lugar: Ur. Humboldt, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-e9cf-7866ade8a977-e13278f9-a602-4235
# Precio: S/.245,000, Lugar: Lurin, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-40-479e37126484-dbbfc926-8f85-4635
# Precio: S/.395,000, Lugar: Castilla, Piura, Enlace: https://www.properati.com.pe/detalle/14032-32-a88f-db19117fd35f-db7d134f-8ef3-4ac1
# Precio: USD330,000, Lugar: Ur. Pro Quinto Sector Ii Etapa, Los Olivos, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-daaa-a7ed7999e37a-db1fd7ec-bf51-4818
# Precio: USD1,600,000, Lugar: Hu. Cercado De Miraflores, Miraflores, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-ecdf-27843598cf70-d8da7e90-9520-4a02
# Precio: USD3,750,000, Lugar: Ur. Cerros De Camacho, Santiago de Surco, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-3df9-114eeae511fc-d2a37951-b279-489f
# Precio: USD300,000, Lugar: Ur. La Luz, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-a2ba-bd6a63c866c2-d2950c20-a572-120d
# Precio: USD400,000, Lugar: Ur. El Abanico, Chaclacayo, Lima, Enlace: https://www.properati.com.pe/detalle/14032-32-183c-314700894caf-d09b4fc0-83e0-4542

# %% [markdown]
# ### 3. Primera visualizacion
# - Para esta primera visualizacion se hara uso de la libreria tabulate para un mejor panorama.

# %%
from tabulate import tabulate
data = {'Precio': precios, 'Lugar': lugares, 'Enlace': enlaces}
df = pd.DataFrame(data)

# Mostrar la tabla
print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# +----+--------------+---------------------------------------------------------------------+------------------------------------------------------------------------------------+
# |    | Precio       | Lugar                                                               | Enlace                                                                             |
# |----+--------------+---------------------------------------------------------------------+------------------------------------------------------------------------------------|
# |  0 | USD750,000   | Los Rosales, Provincia de Lima                                      | https://www.properati.com.pe/detalle/14032-32-d7f6-3fe40920d3be-e9c394a9-8bef-4b13 |
# |  1 | USD560,000   | Ur. Casuarinas Sur, Santiago de Surco, Lima                         | https://www.properati.com.pe/detalle/14032-32-5348-5f529e01db4d-e946fa75-a559-43e8 |
# |  2 | USD630,000   | La Encantada De Villa, Provincia de Lima, Gobierno Regional de Lima | https://www.properati.com.pe/detalle/14032-32-3637-534a8607857f-e1a2f61b-8dc1-4618 |
# |  3 | USD320,000   | A.h General Jose de San Martin, Provincia de Lima                   | https://www.properati.com.pe/detalle/14032-32-c653-9f73ed1f4354-c0829117-a5c7-4ee1 |
# |  4 | USD640,000   | Ur. Jacaranda, San Borja, Lima                                      | https://www.properati.com.pe/detalle/14032-32-84a8-44ce0143a76-ae76846c-97f1-4170  |
# |  5 | USD512,000   | Ur. Aurora, Miraflores, Lima                                        | https://www.properati.com.pe/detalle/14032-32-a476-2760419c7547-9b004e79-b2cc-4829 |
# |  6 | USD149,000   | Nuevo Chimbote, Santa, Ancash                                       | https://www.properati.com.pe/detalle/14032-32-3a85-1e3ffe3b76e0-89bfbb65-afd5-4f8c |
# |  7 | USD365,000   | Ur. Santa Patricia Etapa I, La Molina, Lima                         | https://www.properati.com.pe/detalle/14032-32-f007-1587436fbe65-891f0b5b-8d37-485e |
# |  8 | S/.415,000   | Castilla, Piura                                                     | https://www.properati.com.pe/detalle/14032-32-18a2-fb30be3aa841-6f39d440-870a-120e |
# |  9 | USD400,000   | Ah. Bocanegra Sector F, Callao                                      | https://www.properati.com.pe/detalle/14032-32-ce5f-66b002acd446-3f216980-92f5-415a |
# | 10 | USD1,300,000 | San Isidro, Lima                                                    | https://www.properati.com.pe/detalle/14032-32-c858-e714d33b4c94-29b6433f-b268-4727 |
# | 11 | USD2,500,000 | Ur. Humboldt, Miraflores, Lima                                      | https://www.properati.com.pe/detalle/14032-32-2e96-4a06117c3594-263d48ae-976f-4390 |
# | 12 | USD1,100,000 | Ur. Santa Ines, San Isidro, Lima                                    | https://www.properati.com.pe/detalle/14032-32-60f8-147c0685e41d-24aad2e0-b605-4563 |
# | 13 | S/.790,000   | Castilla, Piura                                                     | https://www.properati.com.pe/detalle/14032-32-7d43-ed83c7cd1d6c-1f1b8b93-9fbb-4e09 |
# | 14 | USD400,000   | Ur. Juan Xxiii, San Borja, Lima                                     | https://www.properati.com.pe/detalle/14032-32-1de0-a49b0a4a7617-49ab306-a685-4d63  |
# | 15 | USD1,750,000 | Country Club, Urb Risso, Provincia de Lima                          | https://www.properati.com.pe/detalle/14032-32-bdef-a876d2a7b64a-2b73c23-a997-4302  |
# | 16 | USD210,000   | Ur. San Miguelito, San Miguel, Lima                                 | https://www.properati.com.pe/detalle/14032-32-f42a-f4904ff4422-fe8aa36c-8f8d-4cec  |
# | 17 | USD149,000   | Ur. Las Delicias De Villa, Chorrillos, Lima                         | https://www.properati.com.pe/detalle/14032-32-5cbd-99632ff875cb-f99b05f8-aa3f-43da |
# | 18 | USD363,000   | Chaclacayo, Lima                                                    | https://www.properati.com.pe/detalle/14032-32-9813-2e1f9a2b1223-f06c527f-8a56-462f |
# | 19 | USD280,000   | Huarochirí, Lima                                                    | https://www.properati.com.pe/detalle/14032-32-cc32-a106eec6a716-ef9ee19c-9f17-4e18 |
# | 20 | USD980,000   | La Molina, Lima                                                     | https://www.properati.com.pe/detalle/14032-32-1625-2d8e36a03b9e-ed5a7520-9587-120e |
# | 21 | USD165,000   | San Martín de Porres, Lima                                          | https://www.properati.com.pe/detalle/14032-32-728a-e1eac6c25ba8-e7a3554b-a169-4bd6 |
# | 22 | USD600,000   | Ur. Humboldt, Miraflores, Lima                                      | https://www.properati.com.pe/detalle/14032-32-e9cf-7866ade8a977-e13278f9-a602-4235 |
# | 23 | S/.245,000   | Lurin, Lima                                                         | https://www.properati.com.pe/detalle/14032-32-40-479e37126484-dbbfc926-8f85-4635   |
# | 24 | S/.395,000   | Castilla, Piura                                                     | https://www.properati.com.pe/detalle/14032-32-a88f-db19117fd35f-db7d134f-8ef3-4ac1 |
# | 25 | USD330,000   | Ur. Pro Quinto Sector Ii Etapa, Los Olivos, Lima                    | https://www.properati.com.pe/detalle/14032-32-daaa-a7ed7999e37a-db1fd7ec-bf51-4818 |
# | 26 | USD1,600,000 | Hu. Cercado De Miraflores, Miraflores, Lima                         | https://www.properati.com.pe/detalle/14032-32-ecdf-27843598cf70-d8da7e90-9520-4a02 |
# | 27 | USD3,750,000 | Ur. Cerros De Camacho, Santiago de Surco, Lima                      | https://www.properati.com.pe/detalle/14032-32-3df9-114eeae511fc-d2a37951-b279-489f |
# | 28 | USD300,000   | Ur. La Luz, Lima                                                    | https://www.properati.com.pe/detalle/14032-32-a2ba-bd6a63c866c2-d2950c20-a572-120d |
# | 29 | USD400,000   | Ur. El Abanico, Chaclacayo, Lima                                    | https://www.properati.com.pe/detalle/14032-32-183c-314700894caf-d09b4fc0-83e0-4542 |
# +----+--------------+---------------------------------------------------------------------+------------------------------------------------------------------------------------+

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4. Segunda visualizacion
# - Se procede a descargar el data frame como un excel, de tal forma que facilite al usuario.

# %%
# Guardar el DataFrame en un archivo Excel
nombre_archivo = 'datos_casas.xlsx'
df.to_excel(nombre_archivo, index=False)
print(f'Los datos se han guardado exitosamente en el archivo {nombre_archivo}')
# Out:
# Los datos se han guardado exitosamente en el archivo datos_casas.xlsx

# %% [markdown]
# ![image.png](attachment:image.png)

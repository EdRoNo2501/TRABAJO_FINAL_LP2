# %% [markdown]
# # The economist Web scraping

# %%
from bs4 import BeautifulSoup
import requests
from googletrans import Translator
import pandas as pd

# %%
# Crear listas para almacenar los datos
titles = []
dates = []
references = []
links = []

translator = Translator()
base_url = "https://www.economist.com/search?q=dollar&page={}"

for page in range(1, 9):  
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    results = soup.find_all("li", class_="_result-item")

    for result in results:
        title = result.find("span", class_="_headline").text.strip()
        date_and_reference = result.find("p", class_="_snippet").text.strip()
        link = result.find("a", class_="_search-result")["href"]

        # Verificar si la cadena contiene "..."
        if "..." in date_and_reference:
            # Extraer la fecha y referencia
            date, reference = date_and_reference.split("...", 1)
            date = date.strip()

            # Traducir el título y la referencia al español
            title = translator.translate(title, dest='es').text
            reference = translator.translate(reference, dest='es').text if reference else ""
        else:
            # Asignar la cadena completa a la fecha y establecer la referencia como vacía
            date = date_and_reference

        # Traducir el título al español
        title = translator.translate(title, dest='es').text
        
        # Agregar los datos a las listas
        titles.append(title)
        dates.append(date)
        references.append(reference.strip())
        links.append(link)

# %%
# Crear un DataFrame
df = pd.DataFrame({"Titulo": titles, "Fecha": dates, "Referencia": references, "Enlace": links})

# Guardar como archivo CSV
df.to_csv("Articulos.The_Economist.csv", index=False)

# %%
df
# Out:
#                                                Titulo  \
# 0   ¿Puede la eliminación de carbono convertirse e...
# 1   ¿Podrían los sistemas de pagos digitales ayuda...
# 2   La mano de obra en la prisión es una industria...
# 3                             El dólar que desaparece
# 4   El poderoso dólar: la moneda de Estados Unidos...
# ..                                                ...
# 75                 Volver al dólar, billetes de dólar
# 76                                 En dólares confían
# 77                                    "¿Solo el mal?"
# 78                      Mastín de millones de dólares
# 79                                 Abajo con el dólar
#
#                                                 Fecha  \
# 0                                        May 21, 2023
# 1                                        May 15, 2023
# 2                                        Mar 16, 2017
# 3   The disappearing dollar. How long can it remai...
# 4                                         Dec 3, 2016
# ..                                                ...
# 75                                       Jun 29, 2011
# 76                                       Apr 27, 2013
# 77                                       Apr 27, 2013
# 78                                       Dec 12, 2015
# 79                                       Oct 20, 2009
#
#                                            Referencia  \
# 0   ¿Puede la eliminación de carbono convertirse e...
# 1   ¿Podría la financiación digital reducir la dep...
# 2   La mano de obra en prisión es una industria de...
# 3
# 4   The Mighty Dollar: America's Moneda, el proble...
# ..                                                ...
# 75  Niall Ferguson, un historiador británico, incl...
# 76  En dólares confían.Viernes sucios, queridos cr...
# 77  Los estudiantes atletas no remunerados están e...
# 78  Mastrosfifes de millones de dólares.La represi...
# 79  Shutterstock.El 5 de marzo, un índice del valo...
#
#                                                Enlace
# 0   https://www.economist.com/business/2023/05/21/...
# 1   https://www.economist.com/special-report/2023/...
# 2   https://www.economist.com/united-states/2017/0...
# 3   https://www.economist.com/leaders/2004/12/02/t...
# 4   https://www.economist.com/weeklyedition/2016-1...
# ..                                                ...
# 75  https://www.economist.com/prospero/2011/06/29/...
# 76  https://www.economist.com/finance-and-economic...
# 77  https://www.economist.com/united-states/2013/0...
# 78  https://www.economist.com/china/2015/12/12/mil...
# 79  https://www.economist.com/finance-and-economic...
#
# [80 rows x 4 columns]

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      -------------------------------------- 232.6/232.6 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2

# %%
# Abre el archivo PDF
with open('06-informe-tecnico-variacion-de-precios-may-2023_1.pdf', 'rb') as file:
    # Crea un objeto de lectura PDF
    pdf_reader = PyPDF2.PdfReader(file)

    # Obtiene el número de páginas del PDF
    num_pages = pdf_reader.numPages

    # Itera sobre cada página del PDF
    for page_number in range(num_pages):
        # Obtiene el contenido de la página
        page = pdf_reader.getPage(page_number)
        content = page.extractText()

        # Busca el patrón de la inflación en el contenido de la página
        pattern = r'(\d+\.\d+)'
        matches = re.findall(pattern, content)

        # Imprime los resultados
        for match in matches:
            print("Inflación:", match)
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[34], line 7
#       4 pdf_reader = PyPDF2.PdfReader(file)
#       6 # Obtiene el número de páginas del PDF
# ----> 7 num_pages = pdf_reader.numPages
#       9 # Itera sobre cada página del PDF
#      10 for page_number in range(num_pages):
#      11     # Obtiene el contenido de la página
#
# File ~\anaconda3\lib\site-packages\PyPDF2\_reader.py:467, in PdfReader.numPages(self)
#     460 @property
#     461 def numPages(self) -> int:  # pragma: no cover
#     462     """
#     463     .. deprecated:: 1.28.0
#     464
#     465         Use :code:`len(reader.pages)` instead.
#     466     """
# --> 467     deprecation_with_replacement("reader.numPages", "len(reader.pages)", "3.0.0")
#     468     return self._get_num_pages()
#
# File ~\anaconda3\lib\site-packages\PyPDF2\_utils.py:369, in deprecation_with_replacement(old_name, new_name, removed_in)
#     363 def deprecation_with_replacement(
#     364     old_name: str, new_name: str, removed_in: str = "3.0.0"
#     365 ) -> None:
#     366     """
#     367     Raise an exception that a feature was already removed, but has a replacement.
#     368     """
# --> 369     deprecation(DEPR_MSG_HAPPENED.format(old_name, removed_in, new_name))
#
# File ~\anaconda3\lib\site-packages\PyPDF2\_utils.py:351, in deprecation(msg)
#     350 def deprecation(msg: str) -> None:
# --> 351     raise DeprecationError(msg)
#
# DeprecationError: reader.numPages is deprecated and was removed in PyPDF2 3.0.0. Use len(reader.pages) instead.
